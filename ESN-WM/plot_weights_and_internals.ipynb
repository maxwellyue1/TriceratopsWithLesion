# %%
import numpy as np
import matplotlib.pyplot as plt

W_out = np.load("W_out.npy")
print(W_out.shape)
dim_out, num_neurons = W_out.shape
plt.scatter(x=np.arange(stop=num_neurons), y=np.squeeze(W_out))
# Out:
# (1, 1000)

# %%
plt.hist(np.squeeze(W_out))
# Out:
# (array([  1.,   9.,  22.,  70., 288., 401., 154.,  42.,  12.,   1.]),
#  array([-0.41159639, -0.33392631, -0.25625623, -0.17858615, -0.10091607,
#         -0.02324599,  0.0544241 ,  0.13209418,  0.20976426,  0.28743434,
#          0.36510442]),
#  <BarContainer object of 10 artists>)

# %%
internals = np.load("test_internals.npy")
print(internals.shape)
for n in range(3):
    plt.plot(internals[:, n])
# Out:
# (2501, 1000)
